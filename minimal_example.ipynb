# %%
import sys, os
import pandas as pd
pd.set_option('display.max_columns', 5) # Show 5 columns for readability.
from derm7pt.dataset import Derm7PtDatasetGroupInfrequent

# Points to the directory that contains the data.
# dir_release = sys.argv[1] # '/local-scratch/jer/data/argenziano/release_v0'
dir_release = "D:/COLLEGE/PROJECTS/(incomplete) 7 point checklist/derm7pt/release_v0"
# Dataset after grouping infrequent labels.
derm_data = Derm7PtDatasetGroupInfrequent(
    dir_images=os.path.join(dir_release, 'images'), 
    metadata_df=pd.read_csv(os.path.join(dir_release, 'meta/meta.csv')), 
    train_indexes=list(pd.read_csv(os.path.join(dir_release, 'meta/train_indexes.csv'))['indexes']), 
    valid_indexes=list(pd.read_csv(os.path.join(dir_release, 'meta/valid_indexes.csv'))['indexes']), 
    test_indexes=list(pd.read_csv(os.path.join(dir_release, 'meta/test_indexes.csv'))['indexes']))

# Outputs to screen the first 5 rows of the preprocessed dataset in a Pandas format.
derm_data.df.head().T
# Out:
# C:\Users\abhay\AppData\Local\Temp\ipykernel_26332\1920014091.py:11: DeprecationWarning: `alltrue` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `all` instead.
#   derm_data = Derm7PtDatasetGroupInfrequent(
#                                                    0                     1  \
# case_num                                           1                     2
# diagnosis                       basal cell carcinoma  basal cell carcinoma
# seven_point_score                                  0                     1
# pigment_network                               absent                absent
# streaks                                       absent                absent
# pigmentation                                  absent                absent
# regression_structures                         absent                absent
# dots_and_globules                             absent             irregular
# blue_whitish_veil                             absent                absent
# vascular_structures                       arborizing                absent
# level_of_diagnostic_difficulty                medium                   low
# elevation                                    nodular              palpable
# location                                     abdomen             head neck
# sex                                           female                female
# management                                  excision              excision
# clinic                                NEL/NEL025.JPG        NEL/NEL027.JPG
# derm                                  NEL/Nel026.jpg        NEL/Nel028.jpg
# case_id                                          NaN                   NaN
# notes                                            NaN                   NaN
# diagnosis_numeric                                  0                     0
# pigment_network_numeric                            0                     0
# blue_whitish_veil_numeric                          0                     0
# vascular_structures_numeric                        1                     0
# pigmentation_numeric                               0                     0
# streaks_numeric                                    0                     0
# dots_and_globules_numeric                          0                     2
# regression_structures_numeric                      0                     0
#
#                                                    2                     3  \
# case_num                                           3                     4
# diagnosis                       basal cell carcinoma  basal cell carcinoma
# seven_point_score                                  1                     4
# pigment_network                               absent                absent
# streaks                                       absent                absent
# pigmentation                                  absent                absent
# regression_structures                         absent            blue areas
# dots_and_globules                          irregular             irregular
# blue_whitish_veil                             absent               present
# vascular_structures                       arborizing     within regression
# level_of_diagnostic_difficulty                medium                   low
# elevation                                   palpable              palpable
# location                                   head neck           lower limbs
# sex                                           female                  male
# management                                  excision              excision
# clinic                                NEL/Nel032.jpg        NEL/NEL034.JPG
# derm                                  NEL/Nel033.jpg        NEL/Nel035.jpg
# case_id                                          NaN                   NaN
# notes                                            NaN                   NaN
# diagnosis_numeric                                  0                     0
# pigment_network_numeric                            0                     0
# blue_whitish_veil_numeric                          0                     1
# vascular_structures_numeric                        1                     1
# pigmentation_numeric                               0                     0
# streaks_numeric                                    0                     0
# dots_and_globules_numeric                          2                     2
# regression_structures_numeric                      0                     1
#
#                                                    4
# case_num                                           5
# diagnosis                       basal cell carcinoma
# seven_point_score                                  1
# pigment_network                               absent
# streaks                                       absent
# pigmentation                       diffuse irregular
# regression_structures                         absent
# dots_and_globules                             absent
# blue_whitish_veil                             absent
# vascular_structures                           absent
# level_of_diagnostic_difficulty                  high
# elevation                                   palpable
# location                                 upper limbs
# sex                                           female
# management                                  excision
# clinic                                NEL/NEL036.JPG
# derm                                  NEL/Nel037.jpg
# case_id                                          NaN
# notes                                            NaN
# diagnosis_numeric                                  0
# pigment_network_numeric                            0
# blue_whitish_veil_numeric                          0
# vascular_structures_numeric                        0
# pigmentation_numeric                               2
# streaks_numeric                                    0
# dots_and_globules_numeric                          0
# regression_structures_numeric                      0
